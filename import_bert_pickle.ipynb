# %%
import pandas as pd
import numpy as np

# %%
## Code in this notebook developed in conjunction with Caroline and with help from https://towardsdatascience.com/calculating-document-similarities-using-bert-and-other-models-b2c1a29c9630

# %%
with open('./pairwise_differences.npy', 'rb') as f:
    pairwise_differences = np.load(f)
with open('./pairwise_similarities.npy', 'rb') as f:
    pairwise_similarities = np.load(f)

# %%
df = pd.read_csv('./sutta_csv/cleaned/df_mn2.csv')
df.head(3)
# Out:
#                                           title  \
# 0  MN 1  Mūlapariyāya Sutta | The Root Sequence
# 1     MN 2  Sabbāsava Sutta | All the Effluents
# 2     MN 4  Bhaya-bherava Sutta | Fear & Terror
#
#                                         title_url   ref  \
# 0  https://www.dhammatalks.org/suttas/MN/MN1.html  MN 1
# 1  https://www.dhammatalks.org/suttas/MN/MN2.html  MN 2
# 2  https://www.dhammatalks.org/suttas/MN/MN4.html  MN 4
#
#                                                                                                                                                                                                                                                                                                     summary  \
# ...

# %%
df['ref'] = df['ref'].str.replace('\u2009', ' ')

# %%
def get_ix(ref):
    ''' Returns an index number based off of a string ID. '''
    return df[df['ref'] == ref].index[0]

# %%
def most_similar(doc_id, similarity_matrix, matrix_type, number):
    '''
  doc_id: (str) unique document identifier
  similarity_matrix: (ndarray) cosine similarity or euclidean difference matrix
  matrix_type: (str) 'cosine' or 'euclidean'
  number: (int) n of similar suttas to display
    '''
    doc_ix = get_ix(doc_id)
    if matrix_type == 'cosine':
        similar_ix = np.argsort(similarity_matrix[doc_ix])[::-1][1:]
    elif matrix_type == 'euclidean':
        similar_ix = np.argsort(similarity_matrix[doc_ix])
    for ix in similar_ix[:number]:
        if ix == doc_ix:
            pass
        else:
            print(f'Title: {df.iloc[ix]["title"]}')

# %%
most_similar('MN 5', similarity_matrix=pairwise_similarities, matrix_type='cosine', number =7)
# Out:
# Title: MN 45  Cūḷa Dhammasamādāna Sutta | The Shorter Discourse on Taking on Practices
# Title: MN 138  Uddesa-vibhaṅga Sutta | An Analysis of the Statement
# Title: MN 149  Mahā Saḷāyatanika Sutta | The Great Six Sense-Media Discourse
# Title: MN 11  Cūḷasīhanāda Sutta | The Shorter Lion’s Roar Discourse
# Title: MN 113  Sappurisa Sutta | A Person of Integrity
# Title: MN 19  Dvedhāvitakka Sutta | Two Sorts of Thinking
# Title: MN 2  Sabbāsava Sutta | All the Effluents
